# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dg = pd.read_csv('DrugReview_processed.csv')
columns = ['Disease', 'Symptoms', 'Count']
ds= pd.read_csv("Symptoms_processed.csv", names = columns, encoding ="ISO-8859-1")

# %%
dg.head()
# Out:
#    uniqueID                  drugName                     condition  \
# 0    206461                 Valsartan  Left Ventricular Dysfunction
# 1     95260                Guanfacine                          ADHD
# 2     92703                    Lybrel                 Birth Control
# 3    138000                Ortho Evra                 Birth Control
# 4     35696  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating        date  \
# 0  "It has no side effect, I take it in combinati...       9  2012-05-20
# 1  "My son is halfway through his fourth week of ...       8  2010-04-27
# 2  "I used to take another oral contraceptive, wh...       5  2009-12-14
# 3  "This is my first time using any form of birth...       8  2015-11-03
# 4  "Suboxone has completely turned my life around...       9  2016-11-27
#
#    usefulCount
# 0           27
# 1          192
# 2           17
# 3           10
# 4           37

# %%
data_drugs = dg.drop(['uniqueID', 'date'], axis = 1)
data_drugs.head()
# Out:
#                    drugName                     condition  \
# 0                 Valsartan  Left Ventricular Dysfunction
# 1                Guanfacine                          ADHD
# 2                    Lybrel                 Birth Control
# 3                Ortho Evra                 Birth Control
# 4  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating  usefulCount
# 0  "It has no side effect, I take it in combinati...       9           27
# 1  "My son is halfway through his fourth week of ...       8          192
# 2  "I used to take another oral contraceptive, wh...       5           17
# 3  "This is my first time using any form of birth...       8           10
# 4  "Suboxone has completely turned my life around...       9           37

# %%
ds.head()
# Out:
#                  Disease                                           Symptoms  \
# 0                Disease                                            Symptom
# 1  hypertensive  disease  ['pain  chest', 'shortness  of breath', 'dizzi...
# 2               diabetes  ['polyuria', 'polydypsia', 'shortness  of brea...
# 3     depression  mental  ['feeling  suicidal', 'suicidal', 'hallucinati...
# 4    depressive disorder  ['feeling  suicidal', 'suicidal', 'hallucinati...
#
#    Count
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
data_symptoms=ds.drop('Count',axis=1)
data_symptoms.head()
# Out:
#                  Disease                                           Symptoms
# 0                Disease                                            Symptom
# 1  hypertensive  disease  ['pain  chest', 'shortness  of breath', 'dizzi...
# 2               diabetes  ['polyuria', 'polydypsia', 'shortness  of brea...
# 3     depression  mental  ['feeling  suicidal', 'suicidal', 'hallucinati...
# 4    depressive disorder  ['feeling  suicidal', 'suicidal', 'hallucinati...

# %%
data_drugs = data_drugs.rename(columns={"condition": "Disease"})

# %%
data_drugs.dropna(axis = 0, inplace=True)
data_drugs.sort_values(by = ['Disease'], ascending= False , inplace= True)
data_drugs.head()
# Out:
#             drugName      Disease  \
# 101227    Nabumetone  zen Shoulde
# 171789         Aleve  zen Shoulde
# 79807   Indomethacin  zen Shoulde
# 49083        Indocin  zen Shoulde
# 113572    Diclofenac  zen Shoulde
#
#                                                    review  rating  usefulCount
# 101227  "The only side effect I have experienced with ...       1            6
# 171789  "Very little relief.  I finished PT and after ...       2            6
# 79807                                         "It works."      10           12
# 49083                                         "It works."      10           12
# 113572  "While taking this medication I had increased ...       9           13

# %%
data_drugs['Disease'].unique()
# Out:
# array(['zen Shoulde', "von Willebrand's Disease", 'ungal Pneumonia',
#        'ungal Infection Prophylaxis', 'unctional Gastric Disorde',
#        'tic (mycophenolic acid)',
#        't Pac with Cyclobenzaprine (cyclobenzaprine)', 't Care',
#        'mulation) (phenylephrine)', 'moterol)', 'moterol / mometasone)',
#        'mist (', 'mis', 'min)', 'min / sitagliptin)',
#        'min / saxagliptin)', 'min / rosiglitazone)',
#        'min / pioglitazone)', 'me', 'mance Anxiety', 'm Pain Disorde',
#        'llicular Lymphoma', 'llicle Stimulation', 'lic Acid Deficiency',
#        'ibromyalgia', 'ibrocystic Breast Disease',
#        'ge HCT (amlodipine / hydrochlorothiazide / valsartan)',
#        'ge (amlodipine / valsartan)', 'eve', 'emale Infertility',
#        'cal Segmental Glomerulosclerosis', 'atigue',
#        'amilial Mediterranean Feve',
#        'amilial Cold Autoinflammatory Syndrome', 'ailure to Thrive',
#        'actor IX Deficiency', 'acial Wrinkles', 'acial Lipoatrophy',
# ...

# %%
data_symptoms.dropna(axis = 0, inplace=True)
data_symptoms.sort_values(by = ['Disease'], ascending= False , inplace= True)
data_symptoms.head()
# Out:
#                             Disease  \
# 81     upper  respiratory infection
# 74                    ulcer  peptic
# 98   tricuspid  valve insufficiency
# 57       transient  ischemic attack
# 111           tonic-clonic seizures
#
#                                               Symptoms
# 81   ['cough', 'throat sore', 'wheezing', 'shortnes...
# 74   ['pain abdominal', 'paraparesis', 'nausea', 'v...
# 98   ['shortness of breath', 'pain', 'vomiting', 'n...
# 57   ['speech slurred', 'dysarthria', 'facial pares...
# 111  ['drowsiness', 'lip smacking', 'myoclonus', 't...

# %%
data_drugs['Disease'] = data_drugs['Disease'].str.lower()
data_symptoms['Disease'] = data_symptoms['Disease'].str.lower()

# %%
merged_data = pd.merge(data_drugs, data_symptoms, on='Disease')

# %%
merged_data.head()
# Out:
#       drugName        Disease  \
# 0   Olanzapine  schizophrenia
# 1  Ziprasidone  schizophrenia
# 2     Loxapine  schizophrenia
# 3  Ziprasidone  schizophrenia
# 4      Abilify  schizophrenia
#
#                                               review  rating  usefulCount  \
# 0  "This drug saved my life, I had been on almost...      10            6
# 1  "Geodon is a very effective drug for me.  Comp...      10           33
# 2  "This medicine completely changed my life in t...      10           22
# 3  "I&#039;ve been on geodon for about three week...       7            6
# 4  "I switched from Risperidal to Abilify two yea...      10           53
#
#                                             Symptoms
# 0  ['hallucinations auditory', 'hypersomnolence',...
# 1  ['hallucinations auditory', 'hypersomnolence',...
# 2  ['hallucinations auditory', 'hypersomnolence',...
# 3  ['hallucinations auditory', 'hypersomnolence',...
# 4  ['hallucinations auditory', 'hypersomnolence',...

# %%
merged_data.shape
# Out:
# (8906, 6)

# %%
merged_data.columns = ['Drug', 'Disease', 'Review','Rating' ,'UsefulCount', 'Symptoms']

# %%
merged_data['Disease'].nunique()
# Out:
# 21

# %%
merged_data['Drug'].nunique()
# Out:
# 302

# %%
merged_data.head()
# Out:
#           Drug        Disease  \
# 0   Olanzapine  schizophrenia
# 1  Ziprasidone  schizophrenia
# 2     Loxapine  schizophrenia
# 3  Ziprasidone  schizophrenia
# 4      Abilify  schizophrenia
#
#                                               Review  Rating  UsefulCount  \
# 0  "This drug saved my life, I had been on almost...      10            6
# 1  "Geodon is a very effective drug for me.  Comp...      10           33
# 2  "This medicine completely changed my life in t...      10           22
# 3  "I&#039;ve been on geodon for about three week...       7            6
# 4  "I switched from Risperidal to Abilify two yea...      10           53
#
#                                             Symptoms
# 0  ['hallucinations auditory', 'hypersomnolence',...
# 1  ['hallucinations auditory', 'hypersomnolence',...
# 2  ['hallucinations auditory', 'hypersomnolence',...
# 3  ['hallucinations auditory', 'hypersomnolence',...
# 4  ['hallucinations auditory', 'hypersomnolence',...

# %%
merged_data.shape
# Out:
# (8906, 6)

# %%
merged_data.to_csv('Merged_dataset.csv',index=False)
